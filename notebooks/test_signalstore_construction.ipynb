# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
data_path = Path("/mnt/nemar/openneuro/ds004186")
import scipy.io as sio
import numpy as np
import xarray as xr
import os
from os import scandir, walk
from signalstore import UnitOfWorkProvider
# from mongomock import MongoClient
from pymongo.mongo_client import MongoClient
from fsspec.implementations.local import LocalFileSystem
from fsspec import get_mapper
from fsspec.implementations.dirfs import DirFileSystem
import fsspec
import mne
import pandas as pd
import json

# %% [markdown]
# # Healthy Brain Network Data - Resting state
#
# This is an excerpt of the Healthy Brain Network data ([data paper](https://www.nature.com/articles/sdata2017181)). The resting state portion as been formatted with BIDS ([Brain Imaging Data Structure](https://bids-specification.readthedocs.io/en/stable/)) format, and made publicly available on [Openneuro](https://openneuro.org/datasets/ds004186/versions/2.0.0) (it's a large dataset so browsing latency might be lagging)
#
# ## EEG Files
# Data is organized by subject. Each subject (`sub-*`) directory has an `eeg` directory storing the eeg data and its associated metadata.
# `*_eeg.fdt` and `*_eeg.set`: EEG data in EEGLAB format
#
# ## Experiment Information
# Subjects 1-17 were instructed to attend to 'Twenty Thousand Leagues Under the Sea' (20000), played in the left ear
# Subjects 18-33 were instructed to attend to 'Journey to the Centre of the Earth' (Journey), played in the right ear
#
# ## Behavioral Data
# score: Comprehension question scores for attended and unattended stories.
# Format: Subjects x Run x Story (1=Attended, 2=Unattended)
#
# ## Stimuli Data Files
#
# wordVec = List of all the content words for a given trial
# onset_time = Onset time of the word in the corresponding cell of 'wordVec' (given in seconds)
# offset_time = Offset time of the word in the corresponding cell of 'wordVec' (given in seconds)
# sentence_boundaries = Time of sentence close (in seconds)

# %%
def load_eeg_data(bids_data_path):
    for entry in scandir(bids_data_path):
        if entry.is_dir() and entry.name.startswith('sub-'):
            subject_dir = entry.name
            subject = subject_dir.split('-')[1]
            subject_dir_path = bids_data_path / subject_dir
            eeg_dir = subject_dir_path / "eeg"

            tasks = ['EC', 'EO']
            runs  = [list(range(1, 6)), list(range(1, 6))]
            for t, task in enumerate(tasks):
                for run in runs[t]:
                    # get file by name pattern subject_dir*task*run_eeg.set
                    raw_file = eeg_dir / f"{subject_dir}_task-{task}_run-{run}_eeg.set"
                    print('raw file', raw_file)
                    if not os.path.exists(raw_file):
                        continue

                    EEG = mne.io.read_raw_eeglab(os.path.join(raw_file), preload=True)
                    eeg_data = EEG.get_data()

                    print('data shape:', eeg_data.shape)
                    
                    eeg_json_file = eeg_dir / f"{subject_dir}_task-{task}_run-{run}_eeg.json"
                    eeg_json = json.load(eeg_json_file.open())
                    fs = int(eeg_json['SamplingFrequency'])
                    max_time = eeg_data.shape[1] / fs
                    time_steps = np.linspace(0, max_time, eeg_data.shape[1]).squeeze() # in seconds
                    print('time steps', len(time_steps))

                    channel_coords_file = eeg_dir / f"{subject_dir}_task-{task}_run-{run}_channels.tsv"
                    channel_coords = pd.read_csv(channel_coords_file, sep='\t') 
                    print('channel coords file len', len(channel_coords))
                    # get channel names from channel_coords
                    channel_names = channel_coords['name'].values
                    print(len(channel_names))
                    eeg_xarray = xr.DataArray(
                        data=eeg_data,
                        dims=['channel','time'],
                        coords={
                            'time': time_steps,
                            'channel': channel_names
                        },
                        attrs={
                            'schema_ref': 'eeg_signal',
                            'data_name': f"{subject_dir}_task-{task}_run-{run}",
                            'subject': f'{subject}',
                            'modality': 'EEG',
                            'task': task,
                            'session_run': run,
                            'sampling_frequency': fs,
                        }
                    )
                    yield eeg_xarray

# count = 0
# for eeg_xarray in load_eeg_data(data_path):
#     if count < 10:
#         print('adding data')
#         # with uow_provider(dataset_name) as uow:
#         #     uow.data.add(eeg_xarray)
            
#         #     uow.commit()
#         count += 1
#     else:
#         break

# %%
filesystem = LocalFileSystem()
# tmp_dir = TemporaryDirectory()
# print(tmp_dir.name)

# Create data storage location
dataset_name = "healthy_brain_network"
store_path = Path("/mnt/nemar/dtyoung/eeg-ssl-data/signalstore/hbn")

# Create a directory for the dataset
if not os.path.exists(store_path):
    os.makedirs(store_path)

tmp_dir_fs = DirFileSystem(
    store_path,
    filesystem=filesystem
)
# client = MongoClient()
uri = "mongodb+srv://dtyoung112:XbiUEbzmCacjafGu@cluster0.6jtigmc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri)

memory_store = {}
uow_provider = UnitOfWorkProvider(
    mongo_client=client,
    filesystem=tmp_dir_fs,
    memory_store=memory_store
)
import json
cwd = Path.cwd()
domain_models_path = cwd.parent / f"DomainModels/{dataset_name}/data_models.json"
metamodel_path = cwd.parent / f"DomainModels/{dataset_name}/metamodels.json"
property_path = cwd.parent / f"DomainModels/{dataset_name}/property_models.json"

with open(metamodel_path) as f:
    metamodels = json.load(f)

with open(property_path) as f:
    property_models = json.load(f)
    
# load domain models json file
with open(domain_models_path) as f:
    domain_models = json.load(f)
    
with uow_provider(dataset_name) as uow:
    for property_model in property_models:
        uow.domain_models.add(property_model)
        model = uow.domain_models.get(property_model['schema_name'])
        print('property model: ', model['schema_name'])
    for metamodel in metamodels:
        uow.domain_models.add(metamodel)
        model = uow.domain_models.get(metamodel['schema_name'])
        print('meta model: ', model['schema_name'])
    for domain_model in domain_models:
        uow.domain_models.add(domain_model)
        model = uow.domain_models.get(domain_model['schema_name'])
        print('domain model: ', model['schema_name'])
        uow.commit()
# Out:
# property model:  version_timestamp
# property model:  schema_ref
# property model:  schema_type
# property model:  schema_name
# property model:  schema_title
# property model:  schema_description
# property model:  data_name
# property model:  time_of_save
# property model:  time_of_removal
# property model:  record_type
# property model:  modality
# property model:  json_schema
# property model:  has_file
# property model:  unit_of_measure
# property model:  dimension_of_measure
# property model:  acquisition
# property model:  acquisition_date
# property model:  import_date
# property model:  acquisition_notes
# property model:  data_dimensions
# property model:  shape
# property model:  dtype
# property model:  session_description
# property model:  session_date
# property model:  session_time
# property model:  session_duration
# property model:  session_notes
# property model:  session_run
# property model:  data_ref
# property model:  start_time
# property model:  duration
# property model:  duration_unit
# property model:  animal_species
# property model:  age
# property model:  age_unit
# property model:  age_lower_bound
# property model:  age_upper_bound
# property model:  animal_id
# property model:  tetrode_id
# property model:  tetrode_depth
# property model:  genotype
# property model:  animal_strain
# property model:  stimulus_type
# property model:  stimulus_id
# property model:  stimulus_description
# property model:  recording_length
# property model:  sample_rate
# property model:  arena_shape
# property model:  arena_description
# property model:  study_description
# property model:  arena_height
# property model:  arena_width
# property model:  diameter
# property model:  arena_side_length
# property model:  arena_radius
# property model:  spike_count
# property model:  subject
# property model:  sampling_frequency
# property model:  attending_direction
# property model:  attending_story
# property model:  attend_score
# property model:  nonattend_score
# property model:  original_length
# property model:  story
# property model:  task
# meta model:  record_metamodel
# meta model:  xarray_dataarray_metamodel
# domain model:  eeg_signal
# domain model:  session
# domain model:  stimuli_record
# domain model:  wordvec
# domain model:  offset_times
# domain model:  onset_times
# domain model:  sentence_boundaries
# domain model:  envelope

# %%
for eeg_xarray in load_eeg_data(data_path):
    with uow_provider(dataset_name) as uow:
        query = {
            "schema_ref": "eeg_signal",
            "data_name": eeg_xarray.attrs['data_name']
        }
        sessions = uow.data.find(query)
        if len(sessions) == 0:
            print('adding data', eeg_xarray.attrs['data_name'])
            uow.data.add(eeg_xarray)
            uow.commit()
# Out:
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-1_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-1_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-2_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-2_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EC_run-2
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-3_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-3_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EC_run-3
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-4_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-4_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EC_run-4
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-5_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-5_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EC_run-5
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-1_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-1_eeg.fdt
# Reading 0 ... 9997  =      0.000 ...    19.994 secs...
# data shape: (129, 9998)
# time steps 9998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EO_run-1
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-2_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-2_eeg.fdt
# Reading 0 ... 9997  =      0.000 ...    19.994 secs...
# data shape: (129, 9998)
# time steps 9998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EO_run-2
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-3_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-3_eeg.fdt
# Reading 0 ... 9997  =      0.000 ...    19.994 secs...
# data shape: (129, 9998)
# time steps 9998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EO_run-3
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-4_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-4_eeg.fdt
# Reading 0 ... 9997  =      0.000 ...    19.994 secs...
# data shape: (129, 9998)
# time steps 9998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EO_run-4
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-5_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EO_run-5_eeg.fdt
# Reading 0 ... 9997  =      0.000 ...    19.994 secs...
# data shape: (129, 9998)
# time steps 9998
# channel coords file len 129
# 129
# adding data sub-NDARRW481GFE_task-EO_run-5
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARAE877NER/eeg/sub-NDARAE877NER_task-EC_run-1_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARAE877NER/eeg/sub-NDARAE877NER_task-EC_run-1_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARAE877NER_task-EC_run-1
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARAE877NER/eeg/sub-NDARAE877NER_task-EC_run-2_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARAE877NER/eeg/sub-NDARAE877NER_task-EC_run-2_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARAE877NER_task-EC_run-2
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARAE877NER/eeg/sub-NDARAE877NER_task-EC_run-3_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARAE877NER/eeg/sub-NDARAE877NER_task-EC_run-3_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# 129
# adding data sub-NDARAE877NER_task-EC_run-3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       8 if len(sessions) == 0:
#       9     print('adding data', eeg_xarray.attrs['data_name'])
# ---> 10     uow.data.add(eeg_xarray)
#      11     uow.commit()
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/signalstore/store/repositories.py:591, in DataRepository.add(self, object, data_adapter, versioning_on)
#     589     elif not isinstance(object.attrs.get("version_timestamp"), dttype):
#     590         raise DataRepositoryTypeError(f"'version_timestamp' must be a {dttype} object or the integer 0, not {type(object.attrs.get('version_timestamp'))}.")
# --> 591     ohe = self._add_data_with_file(
#     592         object=object,
#     593         add_timestamp=add_timestamp,
#     594         versioning_on=versioning_on,
#     595         data_adapter=data_adapter
#     596         )
#     597     return ohe
#     598 else:
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/signalstore/store/repositories.py:642, in DataRepository._add_data_with_file(self, object, add_timestamp, versioning_on, data_adapter)
#     636 self._validate(object.attrs)
#     637 self._records.add(
#     638     document=object.attrs,
#     639     timestamp=ohe.timestamp,
#     640     versioning_on=versioning_on
#     641     )
# --> 642 self._data.add(
#     643     data_object=object,
#     644     data_adapter=data_adapter
#     645     )
#     646 self._operation_history.append(ohe)
#     647 return ohe
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/signalstore/store/data_access_objects.py:570, in FileSystemDAO.add(self, data_object, data_adapter)
#     568 data_object = self._serialize(data_object)
#     569 #get os environment variable 'DEBUG' to check if we should print the data_object
# --> 570 data_adapter.write_file(path=path, data_object=data_object)
#     571 self._deserialize(data_object) # undo the serialization in case the object is mutated
#     572 return None
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/signalstore/store/datafile_adapters.py:70, in XarrayDataArrayNetCDFAdapter.write_file(self, path, data_object)
#      68 data_object = self._clean_attributes(data_object)
#      69 with self.filesystem.open(path, mode='wb') as f:
# ---> 70     data_object.to_netcdf(f, engine="scipy")
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/xarray/core/dataarray.py:4121, in DataArray.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    4117 else:
#    4118     # No problems with the name - so we're fine!
#    4119     dataset = self.to_dataset()
# -> 4121 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    4122     dataset,
#    4123     path,
#    4124     mode=mode,
#    4125     format=format,
#    4126     group=group,
#    4127     engine=engine,
#    4128     encoding=encoding,
#    4129     unlimited_dims=unlimited_dims,
#    4130     compute=compute,
#    4131     multifile=False,
#    4132     invalid_netcdf=invalid_netcdf,
#    4133 )
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/xarray/backends/api.py:1353, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1351 finally:
#    1352     if not multifile and compute:
# -> 1353         store.close()
#    1355 if not compute:
#    1356     import dask
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/xarray/backends/scipy_.py:264, in ScipyDataStore.close(self)
#     263 def close(self):
# --> 264     self._manager.close()
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py:356, in DummyFileManager.close(***failed resolving arguments***)
#     354 def close(self, needs_lock=True):
#     355     del needs_lock  # ignored
# --> 356     self._value.close()
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/scipy/io/_netcdf.py:293, in netcdf_file.close(self)
#     291 if hasattr(self, 'fp') and not self.fp.closed:
#     292     try:
# --> 293         self.flush()
#     294     finally:
#     295         self.variables = {}
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/scipy/io/_netcdf.py:403, in netcdf_file.flush(self)
#     394 """
#     395 Perform a sync-to-disk flush if the `netcdf_file` object is in write mode.
#     396
#    (...)
#     400
#     401 """
#     402 if hasattr(self, 'mode') and self.mode in 'wa':
# --> 403     self._write()
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/scipy/io/_netcdf.py:415, in netcdf_file._write(self)
#     413 self._write_dim_array()
#     414 self._write_gatt_array()
# --> 415 self._write_var_array()
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/scipy/io/_netcdf.py:471, in netcdf_file._write_var_array(self)
#     469     # Set the data for all variables.
#     470     for name in variables:
# --> 471         self._write_var_data(name)
#     472 else:
#     473     self.fp.write(ABSENT)
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/scipy/io/_netcdf.py:519, in netcdf_file._write_var_data(self, name)
#     517 # Write data.
#     518 if not var.isrec:
# --> 519     self.fp.write(var.data.tobytes())
#     520     count = var.data.size * var.data.itemsize
#     521     self._write_var_padding(var, var._vsize - count)
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py:422, in LocalFileOpener.write(self, *args, **kwargs)
#     421 def write(self, *args, **kwargs):
# --> 422     return self.f.write(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
with uow_provider(dataset_name) as uow:
    query = {
        # "schema_ref": "eeg_signal",
        # "data_name": "sub-NDARRW481GFE_task-EC_run-2"
    }
    sessions = uow.data.find(query)
    print(len(sessions))
# Out:
# 75

# %%
def remove_all():
    with uow_provider(dataset_name) as uow:
        sessions = uow.data.find({})
        print(len(sessions))
        for i in range(len(sessions)):
            uow.data.remove(session['schema_ref'], session['data_name'])
            uow.commit()

        uow.purge()
        
remove_all()
with uow_provider(dataset_name) as uow:
    sessions = uow.data.find({})
    print(len(sessions))
# Out:
# 0
# 0
