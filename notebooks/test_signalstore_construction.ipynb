# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2

# %%
import sys 
sys.path.append('..')
from libs.signalstore_data_utils import SignalstoreHBN

# %%
signalstore_hbn = SignalstoreHBN()

# %%
signalstore_hbn.load_domain_models()
# Out:
# ---------------------------------------------------------------------------
# DomainRepositoryModelAlreadyExistsError   Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 signalstore_hbn.load_domain_models()
#
# File ~/eeg-ssl/notebooks/../libs/signalstore_data_utils.py:75, in load_domain_models(self)
#      72     domain_models = json.load(f)
#      74 with self.uow as uow:
# ---> 75     for property_model in property_models:
#      76         uow.domain_models.add(property_model)
#      77         model = uow.domain_models.get(property_model['schema_name'])
#
# File ~/eeg-ssl/.venv/lib/python3.10/site-packages/signalstore/store/repositories.py:317, in DomainModelRepository.add(self, model)
#     315 self._validate(model)
#     316 if self._dao.exists(schema_name=model["schema_name"]):
# --> 317     raise DomainRepositoryModelAlreadyExistsError(f"A model with schema_name '{model['schema_name']}' already exists in the repository.")
#     318 try:
# ...

# %%
signalstore_hbn.add_data()
# Out:
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-1_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-1_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-2_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-2_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# channel coords file len 129
# raw file /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-3_eeg.set
# Reading /mnt/nemar/openneuro/ds004186/sub-NDARRW481GFE/eeg/sub-NDARRW481GFE_task-EC_run-3_eeg.fdt
# Reading 0 ... 19997  =      0.000 ...    39.994 secs...
# data shape: (129, 19998)
# time steps 19998
# ...

# %%
signalstore_hbn.query_data({'subject': 'NDARRW481GFE', 'data_name': 'sub-NDARRW481GFE_task-EC_run-2'}, get_data=True)
# Out:
# Found 1 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'sub-NDARRW481GFE_task-EC_run-2',
#   'subject': 'NDARRW481GFE',
#   'modality': 'EEG',
#   'task': 'EC',
#   'session_run': 2,
#   'sampling_frequency': 500,
#   'version_timestamp': 0,
#   'has_file': True,
#   'time_of_save': datetime.datetime(2024, 8, 6, 18, 26, 59, 459304, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None}]

# %%
with signalstore_hbn.uow as uow:
    record = uow.data.get('eeg_signal', 'sub-NDARRW481GFE_task-EC_run-2')
    print(record)
# Out:
# None
